# %%
file = "./FP.vcf"

# %%
from dataclasses import dataclass

# %%
@dataclass
class Event: 
    eid: str
    tid: str
    
    chr1: str
    pos1: str
    gene1: str
    
    chr2: str
    pos2: str 
    gene2: str
    
    sr: str

# %%
event_list  = []
for line in open(file):
    if line.startswith("#"):
        continue

    columns = line.strip().split()
    info  = columns[7].split(";")

    
    event = Event(eid=columns[2],
                  tid=info[-3].split("=")[-1],
                  
                  chr1=columns[0],
                  pos1=columns[1],
        
                  gene1=info[-2].split("=")[-1],

                  chr2=info[0].split("=")[-1],
                  pos2=info[1].split("=")[-1],
                  gene2=info[-1].split("=")[-1],
        
                  sr=info[2].split("=")[-1],
                 )
    
    event_list.append(event)

# %%
event_list
# Out:
# [Event(eid='GF01', tid='GF01', chr1='chr1', pos1='44776032', gene1='RPS8', chr2='chr19', pos2='49491840', gene2='RPL13A', sr='6'),
#  Event(eid='GF02', tid='GF02', chr1='chr11', pos1='809986', gene1='RPLP2', chr2='chr6', pos2='34417453', gene2='RPS10-NUDT3', sr='4'),
#  Event(eid='GF03', tid='GF03', chr1='chr16', pos1='1962059', gene1='RPS2', chr2='chr3', pos2='101576943', gene2='PCNP', sr='7'),
#  Event(eid='GF04', tid='GF04', chr1='chr16', pos1='1964627', gene1='RPS2', chr2='chr3', pos2='101576437', gene2='PCNP', sr='6'),
#  Event(eid='GF05', tid='GF05', chr1='chr11', pos1='63974627', gene1='COX8A', chr2='chrX', pos2='154400912', gene2='RPL10', sr='5'),
#  Event(eid='GF06', tid='GF06', chr1='chr2', pos1='101002701', gene1='RPL31', chr2='chr5', pos2='181236932', gene2='RACK1', sr='4'),
#  Event(eid='GF07', tid='GF07', chr1='chr14', pos1='49586356', gene1='RPS29', chr2='chr6', pos2='34417453', gene2='RPS10-NUDT3', sr='8'),
#  Event(eid='GF08', tid='GF08', chr1='chr19', pos1='58394803', gene1='RPS5', chr2='chr2', pos2='101002701', gene2='RPL31', sr='4'),
#  Event(eid='GF09', tid='GF09', chr1='chrM', pos1='1682', gene1='MT-RNR2', chr2='chrM', pos2='7518', gene2='MT-CO1', sr='4'),
#  Event(eid='GF010', tid='GF010', chr1='chr12', pos1='49129706', gene1='TUBA1B', chr2='chr12', pos2='103947913', gene2='HSP90B1', sr='4'),
#  Event(eid='GF011', tid='GF011', chr1='chr10', pos1='78040696', gene1='RPS24', chr2='chr11', pos2='75399531', gene2='RPS3', sr='4'),
#  Event(eid='GF012', tid='GF012', chr1='chr14', pos1='49586359', gene1='RPS29', chr2='chr9', pos2='133348920', gene2='RPL7A', sr='5'),
#  Event(eid='GF013', tid='GF013', chr1='chr14', pos1='49583578', gene1='RPS29', chr2='chr9', pos2='133348920', gene2='RPL7A', sr='4'),
#  Event(eid='GF014', tid='GF014', chr1='chr5', pos1='181236935', gene1='RACK1', chr2='chr6', pos2='33272091', gene2='RPS18', sr='6'),
#  Event(eid='GF015', tid='GF015', chr1='chr4', pos1='151104639', gene1='RPS3A', chr2='chr5', pos2='181243890', gene2='RACK1', sr='5'),
#  Event(eid='GF016', tid='GF016', chr1='chr4', pos1='113214399', gene1='ANK2', chr2='chr6', pos2='33276504', gene2='RPS18', sr='4'),
#  Event(eid='GF017', tid='GF017', chr1='chr19', pos1='48966878', gene1='FTL', chr2='chr9', pos2='133348920', gene2='RPL7A', sr='4'),
#  Event(eid='GF018', tid='GF018', chr1='chr22', pos1='39312883', gene1='RPL3', chr2='chr8', pos2='56074494', gene2='RPS20', sr='5'),
#  Event(eid='GF019', tid='GF019', chr1='chr1', pos1='96679628', gene1='RPL7P9', chr2='chr11', pos2='812875', gene2='RPLP2', sr='5'),
#  Event(eid='GF020', tid='GF020', chr1='chr11', pos1='75399533', gene1='RPS3', chr2='chr17', pos2='81510678', gene2='ACTG1', sr='4'),
#  Event(eid='GF021', tid='GF021', chr1='chr6', pos1='34417459', gene1='RPS10-NUDT3', chr2='chrX', pos2='154398500', gene2='RPL10', sr='5'),
#  Event(eid='GF022', tid='GF022', chr1='chr6', pos1='34426061', gene1='RPS10-NUDT3', chr2='chrX', pos2='154400912', gene2='RPL10', sr='4'),
#  Event(eid='GF023', tid='GF023', chr1='chr3', pos1='39406731', gene1='RPSA', chr2='chr4', pos2='113213967', gene2='ANK2', sr='4'),
#  Event(eid='GF024', tid='GF024', chr1='chr11', pos1='809979', gene1='RPLP2', chr2='chr4', pos2='151104639', gene2='RPS3A', sr='4'),
#  Event(eid='GF025', tid='GF025', chr1='chr1', pos1='96678796', gene1='RPL7P9', chr2='chr10', pos2='78033867', gene2='RPS24', sr='4'),
#  Event(eid='GF026', tid='GF026', chr1='chr1', pos1='96679628', gene1='RPL7P9', chr2='chr14', pos2='49583578', gene2='RPS29', sr='9'),
#  Event(eid='GF027', tid='GF027', chr1='chr11', pos1='75405688', gene1='RPS3', chr2='chr5', pos2='55944629', gene2='IL6ST', sr='4'),
#  Event(eid='GF028', tid='GF028', chr1='chr18', pos1='49488483', gene1='RPL17-C18orf32', chr2='chr3', pos2='101576987', gene2='PCNP', sr='4'),
#  Event(eid='GF029', tid='GF029', chr1='chr19', pos1='49496445', gene1='RPS11', chr2='chr4', pos2='108625255', gene2='RPL34', sr='4'),
#  Event(eid='GF030', tid='GF030', chr1='chrX', pos1='119786507', gene1='RPL39', chr2='chrX', pos2='154398495', gene2='RPL10', sr='4'),
#  Event(eid='GF031', tid='GF031', chr1='chr17', pos1='81509970', gene1='ACTG1', chr2='chr19', pos2='58387283', gene2='RPS5', sr='4'),
#  Event(eid='GF032', tid='GF032', chr1='chr19', pos1='49499688', gene1='RPS11', chr2='chrX', pos2='154398495', gene2='RPL10', sr='4'),
#  Event(eid='GF033', tid='GF033', chr1='chr14', pos1='49586352', gene1='RPS29', chr2='chr17', pos2='39204721', gene2='RPL19', sr='6'),
#  Event(eid='GF034', tid='GF034', chr1='chr5', pos1='181243894', gene1='RACK1', chr2='chr8', pos2='98041720', gene2='RPL30', sr='5'),
#  Event(eid='GF035', tid='GF035', chr1='chr6', pos1='34417453', gene1='RPS10-NUDT3', chr2='chr8', pos2='98045533', gene2='RPL30', sr='7'),
#  Event(eid='GF036', tid='GF036', chr1='chr6', pos1='132814567', gene1='RPS12', chr2='chr7', pos2='44801627', gene2='PPIA', sr='4'),
#  Event(eid='GF037', tid='GF037', chr1='chr5', pos1='181236934', gene1='RACK1', chr2='chrX', pos2='154398495', gene2='RPL10', sr='8'),
#  Event(eid='GF038', tid='GF038', chr1='chr11', pos1='75399526', gene1='RPS3', chr2='chr8', pos2='98041721', gene2='RPL30', sr='5'),
#  Event(eid='GF039', tid='GF039', chr1='chr11', pos1='119015711', gene1='RPS25', chr2='chr8', pos2='98045532', gene2='RPL30', sr='4'),
#  Event(eid='GF040', tid='GF040', chr1='chr11', pos1='46429150', gene1='AMBRA1', chr2='chr4', pos2='151104636', gene2='RPS3A', sr='4'),
#  Event(eid='GF041', tid='GF041', chr1='chr19', pos1='39433213', gene1='RPS16', chr2='chr2', pos2='171517724', gene2='RPS15P4', sr='4'),
#  Event(eid='GF042', tid='GF042', chr1='chr19', pos1='39433213', gene1='RPS16', chr2='chrX', pos2='154398495', gene2='RPL10', sr='4'),
#  Event(eid='GF043', tid='GF043', chr1='chr19', pos1='55388367', gene1='RPL28', chr2='chrM', pos2='10063', gene2='MT-ND3', sr='4'),
#  Event(eid='GF044', tid='GF044', chr1='chr11', pos1='46429151', gene1='AMBRA1', chr2='chr3', pos2='39412437', gene2='RPSA', sr='7'),
#  Event(eid='GF045', tid='GF045', chr1='chr2', pos1='55232806', gene1='RPS27A', chr2='chr6', pos2='34417453', gene2='RPS10-NUDT3', sr='4'),
#  Event(eid='GF046', tid='GF046', chr1='chr5', pos1='150444237', gene1='RPS14', chr2='chr9', pos2='127451390', gene2='RPL12', sr='5'),
#  Event(eid='GF047', tid='GF047', chr1='chr11', pos1='75399527', gene1='RPS3', chr2='chr6', pos2='34417453', gene2='RPS10-NUDT3', sr='5'),
#  Event(eid='GF048', tid='GF048', chr1='chr16', pos1='1964627', gene1='RPS2', chr2='chr3', pos2='53225653', gene2='TKT', sr='5'),
#  Event(eid='GF049', tid='GF049', chr1='chr17', pos1='38850080', gene1='RPL23', chr2='chr8', pos2='98041720', gene2='RPL30', sr='4'),
#  Event(eid='GF050', tid='GF050', chr1='chr13', pos1='45341174', gene1='TPT1', chr2='chr6', pos2='34417461', gene2='RPS10-NUDT3', sr='6'),
#  Event(eid='GF051', tid='GF051', chr1='chr17', pos1='8377520', gene1='RP11-849F2.7', chr2='chr8', pos2='144792142', gene2='RPL8', sr='4'),
#  Event(eid='GF052', tid='GF052', chr1='chr3', pos1='101686706', gene1='RPL24', chr2='chr9', pos2='127447675', gene2='RPL12', sr='5'),
#  Event(eid='GF053', tid='GF053', chr1='chr10', pos1='120355211', gene1='RPL21P16', chr2='chr19', pos2='49499688', gene2='RPS11', sr='5'),
#  Event(eid='GF054', tid='GF054', chr1='chr10', pos1='120354655', gene1='RPL21P16', chr2='chr19', pos2='49496441', gene2='RPS11', sr='4'),
#  Event(eid='GF055', tid='GF055', chr1='chr19', pos1='39433209', gene1='RPS16', chr2='chr4', pos2='151099640', gene2='RPS3A', sr='4'),
#  Event(eid='GF056', tid='GF056', chr1='chr19', pos1='49487619', gene1='RPL13A', chr2='chrX', pos2='154400912', gene2='RPL10', sr='4'),
#  Event(eid='GF057', tid='GF057', chr1='chr11', pos1='75405688', gene1='RPS3', chr2='chr16', pos2='1964627', gene2='RPS2', sr='4'),
#  Event(eid='GF058', tid='GF058', chr1='chr17', pos1='39201210', gene1='RPL19', chr2='chr19', pos2='50879233', gene2='KLK2', sr='5'),
#  Event(eid='GF059', tid='GF059', chr1='chr11', pos1='63974630', gene1='COX8A', chr2='chr12', pos2='112405189', gene2='RPL6', sr='4'),
#  Event(eid='GF060', tid='GF060', chr1='chr19', pos1='1438808', gene1='RPS15', chr2='chr19', pos2='55388369', gene2='RPL28', sr='4'),
#  Event(eid='GF061', tid='GF061', chr1='chr5', pos1='181236946', gene1='RACK1', chr2='chr9', pos2='124861943', gene2='RPL35', sr='4'),
#  Event(eid='GF062', tid='GF062', chr1='chr11', pos1='75399531', gene1='RPS3', chr2='chr6', pos2='73372919', gene2='OOEP', sr='4'),
#  Event(eid='GF063', tid='GF063', chr1='chr10', pos1='78040696', gene1='RPS24', chr2='chr9', pos2='133348920', gene2='RPL7A', sr='4'),
#  Event(eid='GF064', tid='GF064', chr1='chr19', pos1='49491839', gene1='RPL13A', chr2='chr19', pos2='55386347', gene2='RPL28', sr='4'),
#  Event(eid='GF065', tid='GF065', chr1='chr13', pos1='45341162', gene1='TPT1', chr2='chr9', pos2='133351422', gene2='RPL7A', sr='4'),
#  Event(eid='GF066', tid='GF066', chr1='chr16', pos1='1964627', gene1='RPS2', chr2='chr17', pos2='43002958', gene2='RPL27', sr='4'),
#  Event(eid='GF067', tid='GF067', chr1='chr16', pos1='1962060', gene1='RPS2', chr2='chr17', pos2='42998456', gene2='RPL27', sr='4'),
#  Event(eid='GF068', tid='GF068', chr1='chr19', pos1='49499688', gene1='RPS11', chr2='chrX', pos2='72276234', gene2='PIN4', sr='4'),
#  Event(eid='GF069', tid='GF069', chr1='chr14', pos1='49586364', gene1='RPS29', chr2='chr8', pos2='98041720', gene2='RPL30', sr='7'),
#  Event(eid='GF070', tid='GF070', chr1='chr14', pos1='49586359', gene1='RPS29', chr2='chr16', pos2='1962059', gene2='RPS2', sr='4'),
#  Event(eid='GF071', tid='GF071', chr1='chr19', pos1='49491840', gene1='RPL13A', chr2='chr4', pos2='108621948', gene2='RPL34', sr='7'),
#  Event(eid='GF072', tid='GF072', chr1='chr11', pos1='8683200', gene1='RPL27A', chr2='chrX', pos2='154400912', gene2='RPL10', sr='5'),
#  Event(eid='GF073', tid='GF073', chr1='chr11', pos1='75399536', gene1='RPS3', chr2='chr8', pos2='144789768', gene2='RPL8', sr='4'),
#  Event(eid='GF074', tid='GF074', chr1='chr4', pos1='108625255', gene1='RPL34', chr2='chr8', pos2='56074489', gene2='RPS20', sr='4'),
#  Event(eid='GF075', tid='GF075', chr1='chr10', pos1='78040696', gene1='RPS24', chr2='chr11', pos2='809975', gene2='RPLP2', sr='5'),
#  Event(eid='GF076', tid='GF076', chr1='chr11', pos1='75399530', gene1='RPS3', chr2='chr22', pos2='39312883', gene2='RPL3', sr='8'),
#  Event(eid='GF077', tid='GF077', chr1='chr4', pos1='151104636', gene1='RPS3A', chr2='chr7', pos2='137513832', gene2='DGKI', sr='5'),
#  Event(eid='GF078', tid='GF078', chr1='chr11', pos1='75399531', gene1='RPS3', chr2='chr13', pos2='45337178', gene2='TPT1', sr='5'),
#  Event(eid='GF079', tid='GF079', chr1='chr17', pos1='16439323', gene1='SNHG29', chr2='chr8', pos2='98041720', gene2='RPL30', sr='4'),
#  Event(eid='GF080', tid='GF080', chr1='chr17', pos1='39204721', gene1='RPL19', chr2='chr19', pos2='48965321', gene2='FTL', sr='4'),
#  Event(eid='GF081', tid='GF081', chr1='chr17', pos1='39201210', gene1='RPL19', chr2='chr9', pos2='133351425', gene2='RPL7A', sr='7'),
#  Event(eid='GF082', tid='GF082', chr1='chr10', pos1='78033876', gene1='RPS24', chr2='chr19', pos2='49491836', gene2='RPL13A', sr='4'),
#  Event(eid='GF083', tid='GF083', chr1='chr14', pos1='49586359', gene1='RPS29', chr2='chr17', pos2='43002958', gene2='RPL27', sr='4'),
#  Event(eid='GF084', tid='GF084', chr1='chr11', pos1='809977', gene1='RPLP2', chr2='chr11', pos2='63976542', gene2='COX8A', sr='4'),
#  Event(eid='GF085', tid='GF085', chr1='chr5', pos1='181236928', gene1='RACK1', chr2='chr8', pos2='144792142', gene2='RPL8', sr='4'),
#  Event(eid='GF086', tid='GF086', chr1='chr17', pos1='39204722', gene1='RPL19', chr2='chr17', pos2='74203690', gene2='RPL38', sr='6'),
#  Event(eid='GF087', tid='GF087', chr1='chr9', pos1='127451391', gene1='RPL12', chr2='chrX', pos2='154400911', gene2='RPL10', sr='4'),
#  Event(eid='GF088', tid='GF088', chr1='chr3', pos1='101576440', gene1='PCNP', chr2='chr4', pos2='151099638', gene2='RPS3A', sr='6'),
#  Event(eid='GF089', tid='GF089', chr1='chr19', pos1='50879233', gene1='KLK2', chr2='chrX', pos2='154398498', gene2='RPL10', sr='4'),
#  Event(eid='GF090', tid='GF090', chr1='chr11', pos1='119018334', gene1='RPS25', chr2='chr14', pos2='49583575', gene2='RPS29', sr='4'),
#  Event(eid='GF091', tid='GF091', chr1='chr1', pos1='44776032', gene1='RPS8', chr2='chr3', pos2='40462279', gene2='RPL14', sr='4'),
#  Event(eid='GF092', tid='GF092', chr1='chr3', pos1='101576978', gene1='PCNP', chr2='chr9', pos2='133351425', gene2='RPL7A', sr='5'),
#  Event(eid='GF093', tid='GF093', chr1='chr19', pos1='39435932', gene1='RPS16', chr2='chr19', pos2='49499689', gene2='RPS11', sr='4'),
#  Event(eid='GF094', tid='GF094', chr1='chr13', pos1='45337178', gene1='TPT1', chr2='chr6', pos2='33272089', gene2='RPS18', sr='4'),
#  Event(eid='GF095', tid='GF095', chr1='chr19', pos1='48619167', gene1='RPL18', chr2='chrX', pos2='154400916', gene2='RPL10', sr='6'),
#  Event(eid='GF096', tid='GF096', chr1='chr1', pos1='44778739', gene1='RPS8', chr2='chr10', pos2='120355208', gene2='RPL21P16', sr='4'),
#  Event(eid='GF097', tid='GF097', chr1='chr19', pos1='12643939', gene1='RPL10P16', chr2='chr9', pos2='133351422', gene2='RPL7A', sr='4'),
#  Event(eid='GF098', tid='GF098', chr1='chr17', pos1='39204721', gene1='RPL19', chr2='chr19', pos2='49487619', gene2='RPL13A', sr='5'),
#  Event(eid='GF099', tid='GF099', chr1='chr15', pos1='66504833', gene1='RPL4', chr2='chr9', pos2='124857885', gene2='RPL35', sr='5'),
#  Event(eid='GF0100', tid='GF0100', chr1='chr11', pos1='63974621', gene1='COX8A', chr2='chr19', pos2='49499688', gene2='RPS11', sr='5'),
#  Event(eid='GF0101', tid='GF0101', chr1='chr8', pos1='98045407', gene1='RPL30', chr2='chr9', pos2='133019695', gene2='EEF1A1P5', sr='4'),
#  Event(eid='GF0102', tid='GF0102', chr1='chr17', pos1='39200327', gene1='RPL19', chr2='chr6', pos2='34417453', gene2='RPS10-NUDT3', sr='7'),
#  Event(eid='GF0103', tid='GF0103', chr1='chr11', pos1='809977', gene1='RPLP2', chr2='chr5', pos2='181236934', gene2='RACK1', sr='7'),
#  Event(eid='GF0104', tid='GF0104', chr1='chr17', pos1='8377522', gene1='RP11-849F2.7', chr2='chr9', pos2='124861950', gene2='RPL35', sr='4'),
#  Event(eid='GF0105', tid='GF0105', chr1='chr3', pos1='39412433', gene1='RPSA', chr2='chr6', pos2='153282744', gene2='RP11-306O13.1', sr='4'),
#  Event(eid='GF0106', tid='GF0106', chr1='chr1', pos1='6199583', gene1='RPL22', chr2='chr19', pos2='49491840', gene2='RPL13A', sr='4'),
#  Event(eid='GF0107', tid='GF0107', chr1='chr2', pos1='101006417', gene1='RPL31', chr2='chr6', pos2='34426062', gene2='RPS10-NUDT3', sr='4'),
#  Event(eid='GF0108', tid='GF0108', chr1='chr1', pos1='23692602', gene1='RPL11', chr2='chr5', pos2='150444237', gene2='RPS14', sr='4'),
#  Event(eid='GF0109', tid='GF0109', chr1='chr11', pos1='63974608', gene1='COX8A', chr2='chr14', pos2='49583576', gene2='RPS29', sr='5'),
#  Event(eid='GF0110', tid='GF0110', chr1='chr5', pos1='150449725', gene1='RPS14', chr2='chr9', pos2='133351425', gene2='RPL7A', sr='4'),
#  Event(eid='GF0111', tid='GF0111', chr1='chr17', pos1='74203703', gene1='RPL38', chr2='chr2', pos2='101006417', gene2='RPL31', sr='5'),
#  Event(eid='GF0112', tid='GF0112', chr1='chr17', pos1='28723933', gene1='RPL23A', chr2='chr9', pos2='124861940', gene2='RPL35', sr='5'),
#  Event(eid='GF0113', tid='GF0113', chr1='chr1', pos1='92832049', gene1='RPL5', chr2='chr2', pos2='101006417', gene2='RPL31', sr='4'),
#  Event(eid='GF0114', tid='GF0114', chr1='chr17', pos1='81509970', gene1='ACTG1', chr2='chr19', pos2='39435936', gene2='RPS16', sr='5'),
#  Event(eid='GF0115', tid='GF0115', chr1='chr13', pos1='45341165', gene1='TPT1', chr2='chr6', pos2='132817563', gene2='RPS12', sr='4'),
#  Event(eid='GF0116', tid='GF0116', chr1='chr11', pos1='65122121', gene1='FAU', chr2='chr6', pos2='34417453', gene2='RPS10-NUDT3', sr='5'),
#  Event(eid='GF0117', tid='GF0117', chr1='chr19', pos1='49496442', gene1='RPS11', chr2='chr5', pos2='181236936', gene2='RACK1', sr='6'),
#  Event(eid='GF0118', tid='GF0118', chr1='chr10', pos1='78040696', gene1='RPS24', chr2='chr8', pos2='98045532', gene2='RPL30', sr='5'),
#  Event(eid='GF0119', tid='GF0119', chr1='chr1', pos1='44775583', gene1='RPS8', chr2='chr19', pos2='49499688', gene2='RPS11', sr='4'),
#  Event(eid='GF0120', tid='GF0120', chr1='chr11', pos1='62559600', gene1='EEF1G', chr2='chr5', pos2='181243895', gene2='RACK1', sr='4'),
#  Event(eid='GF0121', tid='GF0121', chr1='chr4', pos1='151099641', gene1='RPS3A', chr2='chr8', pos2='144789768', gene2='RPL8', sr='4'),
#  Event(eid='GF0122', tid='GF0122', chr1='chr10', pos1='120355210', gene1='RPL21P16', chr2='chrX', pos2='154400912', gene2='RPL10', sr='5'),
#  Event(eid='GF0123', tid='GF0123', chr1='chr16', pos1='18782967', gene1='RPS15A', chr2='chr9', pos2='124861555', gene2='RPL35', sr='4'),
#  Event(eid='GF0124', tid='GF0124', chr1='chr17', pos1='43002958', gene1='RPL27', chr2='chrX', pos2='154398495', gene2='RPL10', sr='8'),
#  Event(eid='GF0125', tid='GF0125', chr1='chr6', pos1='34417453', gene1='RPS10-NUDT3', chr2='chr8', pos2='56074493', gene2='RPS20', sr='4'),
#  Event(eid='GF0126', tid='GF0126', chr1='chr5', pos1='150444237', gene1='RPS14', chr2='chr8', pos2='56074494', gene2='RPS20', sr='4'),
#  Event(eid='GF0127', tid='GF0127', chr1='chr19', pos1='49497191', gene1='RPS11', chr2='chr8', pos2='98041720', gene2='RPL30', sr='6'),
#  Event(eid='GF0128', tid='GF0128', chr1='chr17', pos1='39200327', gene1='RPL19', chr2='chr19', pos2='55388369', gene2='RPL28', sr='4'),
#  Event(eid='GF0129', tid='GF0129', chr1='chr19', pos1='49496440', gene1='RPS11', chr2='chr4', pos2='151104636', gene2='RPS3A', sr='7'),
#  Event(eid='GF0130', tid='GF0130', chr1='chr19', pos1='49499688', gene1='RPS11', chr2='chr4', pos2='151099641', gene2='RPS3A', sr='5'),
#  Event(eid='GF0131', tid='GF0131', chr1='chr1', pos1='44776069', gene1='RPS8', chr2='chr9', pos2='133351417', gene2='RPL7A', sr='5'),
#  Event(eid='GF0132', tid='GF0132', chr1='chr5', pos1='181236936', gene1='RACK1', chr2='chr6', pos2='34426054', gene2='RPS10-NUDT3', sr='4'),
#  Event(eid='GF0133', tid='GF0133', chr1='chr17', pos1='39200323', gene1='RPL19', chr2='chr19', pos2='39433209', gene2='RPS16', sr='4'),
#  Event(eid='GF0134', tid='GF0134', chr1='chr12', pos1='112408657', gene1='RPL6', chr2='chr19', pos2='49499688', gene2='RPS11', sr='4'),
#  Event(eid='GF0135', tid='GF0135', chr1='chr11', pos1='46428598', gene1='AMBRA1', chr2='chr9', pos2='127451393', gene2='RPL12', sr='4'),
#  Event(eid='GF0136', tid='GF0136', chr1='chr9', pos1='133351425', gene1='RPL7A', chr2='chrX', pos2='79367315', gene2='ITM2A', sr='4'),
#  Event(eid='GF0137', tid='GF0137', chr1='chr11', pos1='65120986', gene1='FAU', chr2='chr9', pos2='133348920', gene2='RPL7A', sr='4'),
#  Event(eid='GF0138', tid='GF0138', chr1='chr11', pos1='75399533', gene1='RPS3', chr2='chr19', pos2='49491840', gene2='RPL13A', sr='5'),
#  Event(eid='GF0139', tid='GF0139', chr1='chr11', pos1='75399526', gene1='RPS3', chr2='chr19', pos2='49499688', gene2='RPS11', sr='6'),
#  Event(eid='GF0140', tid='GF0140', chr1='chr2', pos1='203191327', gene1='NBEAL1', chr2='chr4', pos2='151099636', gene2='RPS3A', sr='6'),
#  Event(eid='GF0141', tid='GF0141', chr1='chr2', pos1='203190704', gene1='NBEAL1', chr2='chr4', pos2='151104636', gene2='RPS3A', sr='4'),
#  Event(eid='GF0142', tid='GF0142', chr1='chr13', pos1='45341167', gene1='TPT1', chr2='chr3', pos2='40462275', gene2='RPL14', sr='4'),
#  Event(eid='GF0143', tid='GF0143', chr1='chr16', pos1='18789118', gene1='RPS15A', chr2='chr5', pos2='181236936', gene2='RACK1', sr='4'),
#  Event(eid='GF0144', tid='GF0144', chr1='chr1', pos1='96679628', gene1='RPL7P9', chr2='chr2', pos2='101006418', gene2='RPL31', sr='4'),
#  Event(eid='GF0145', tid='GF0145', chr1='chr16', pos1='1964627', gene1='RPS2', chr2='chr8', pos2='98041720', gene2='RPL30', sr='4'),
#  Event(eid='GF0146', tid='GF0146', chr1='chr2', pos1='171517222', gene1='RPS15P4', chr2='chr3', pos2='39406729', gene2='RPSA', sr='4'),
#  Event(eid='GF0147', tid='GF0147', chr1='chr16', pos1='1962059', gene1='RPS2', chr2='chr17', pos2='39201210', gene2='RPL19', sr='4'),
#  Event(eid='GF0148', tid='GF0148', chr1='chr11', pos1='8685845', gene1='RPL27A', chr2='chr11', pos2='75399536', gene2='RPS3', sr='4'),
#  Event(eid='GF0149', tid='GF0149', chr1='chr5', pos1='150444237', gene1='RPS14', chr2='chr6', pos2='33272087', gene2='RPS18', sr='4'),
#  Event(eid='GF0150', tid='GF0150', chr1='chr11', pos1='8685842', gene1='RPL27A', chr2='chr8', pos2='56074484', gene2='RPS20', sr='4'),
#  Event(eid='GF0151', tid='GF0151', chr1='chr1', pos1='23696419', gene1='RPL11', chr2='chr17', pos2='74203686', gene2='RPL38', sr='5'),
#  Event(eid='GF0152', tid='GF0152', chr1='chr19', pos1='49496440', gene1='RPS11', chr2='chr22', pos2='39312883', gene2='RPL3', sr='6'),
#  Event(eid='GF0153', tid='GF0153', chr1='chr11', pos1='812871', gene1='RPLP2', chr2='chr19', pos2='49496443', gene2='RPS11', sr='4'),
#  Event(eid='GF0154', tid='GF0154', chr1='chr1', pos1='44776032', gene1='RPS8', chr2='chr8', pos2='98041720', gene2='RPL30', sr='4'),
#  Event(eid='GF0155', tid='GF0155', chr1='chr11', pos1='809976', gene1='RPLP2', chr2='chr17', pos2='39204717', gene2='RPL19', sr='4'),
#  Event(eid='GF0156', tid='GF0156', chr1='chr10', pos1='120354656', gene1='RPL21P16', chr2='chr11', pos2='75399528', gene2='RPS3', sr='6'),
#  Event(eid='GF0157', tid='GF0157', chr1='chr19', pos1='39433213', gene1='RPS16', chr2='chr6', pos2='34426055', gene2='RPS10-NUDT3', sr='4'),
#  Event(eid='GF0158', tid='GF0158', chr1='chr16', pos1='1964627', gene1='RPS2', chr2='chr2', pos2='101006417', gene2='RPL31', sr='4'),
#  Event(eid='GF0159', tid='GF0159', chr1='chr13', pos1='45341174', gene1='TPT1', chr2='chr17', pos2='74209879', gene2='RPL38', sr='4'),
#  Event(eid='GF0160', tid='GF0160', chr1='chr11', pos1='8685845', gene1='RPL27A', chr2='chr6', pos2='34426057', gene2='RPS10-NUDT3', sr='4'),
#  Event(eid='GF0161', tid='GF0161', chr1='chr16', pos1='18789111', gene1='RPS15A', chr2='chr6', pos2='33276502', gene2='RPS18', sr='4'),
#  Event(eid='GF0162', tid='GF0162', chr1='chr4', pos1='108621948', gene1='RPL34', chr2='chr9', pos2='124857885', gene2='RPL35', sr='5'),
#  Event(eid='GF0163', tid='GF0163', chr1='chr11', pos1='809975', gene1='RPLP2', chr2='chr11', pos2='62559600', gene2='EEF1G', sr='4'),
#  Event(eid='GF0164', tid='GF0164', chr1='chr1', pos1='44778737', gene1='RPS8', chr2='chr2', pos2='101002701', gene2='RPL31', sr='5'),
#  Event(eid='GF0165', tid='GF0165', chr1='chr19', pos1='49489846', gene1='RPL13A', chr2='chr5', pos2='181236946', gene2='RACK1', sr='5'),
#  Event(eid='GF0166', tid='GF0166', chr1='chr19', pos1='39433213', gene1='RPS16', chr2='chr5', pos2='150449724', gene2='RPS14', sr='4'),
#  Event(eid='GF0167', tid='GF0167', chr1='chr15', pos1='66499323', gene1='RPL4', chr2='chr8', pos2='56074494', gene2='RPS20', sr='4'),
#  Event(eid='GF0168', tid='GF0168', chr1='chr1', pos1='23696417', gene1='RPL11', chr2='chr14', pos2='49586363', gene2='RPS29', sr='4'),
#  Event(eid='GF0169', tid='GF0169', chr1='chr1', pos1='96679628', gene1='RPL7P9', chr2='chr19', pos2='49499688', gene2='RPS11', sr='4'),
#  Event(eid='GF0170', tid='GF0170', chr1='chr11', pos1='46428593', gene1='AMBRA1', chr2='chr16', pos2='1964627', gene2='RPS2', sr='5'),
#  Event(eid='GF0171', tid='GF0171', chr1='chr12', pos1='112405189', gene1='RPL6', chr2='chr16', pos2='18789118', gene2='RPS15A', sr='4'),
#  Event(eid='GF0172', tid='GF0172', chr1='chr11', pos1='809987', gene1='RPLP2', chr2='chr19', pos2='39433213', gene2='RPS16', sr='4'),
#  Event(eid='GF0173', tid='GF0173', chr1='chr19', pos1='49491840', gene1='RPL13A', chr2='chr9', pos2='124861555', gene2='RPL35', sr='4'),
#  Event(eid='GF0174', tid='GF0174', chr1='chr15', pos1='66504834', gene1='RPL4', chr2='chr16', pos2='1962060', gene2='RPS2', sr='5'),
#  Event(eid='GF0175', tid='GF0175', chr1='chr12', pos1='112408656', gene1='RPL6', chr2='chr5', pos2='181236931', gene2='RACK1', sr='4'),
#  Event(eid='GF0176', tid='GF0176', chr1='chr17', pos1='28723915', gene1='RPL23A', chr2='chr4', pos2='108621949', gene2='RPL34', sr='5'),
#  Event(eid='GF0177', tid='GF0177', chr1='chr13', pos1='45341167', gene1='TPT1', chr2='chr16', pos2='1962060', gene2='RPS2', sr='5'),
#  Event(eid='GF0178', tid='GF0178', chr1='chr1', pos1='23692607', gene1='RPL11', chr2='chr11', pos2='812865', gene2='RPLP2', sr='4'),
#  Event(eid='GF0179', tid='GF0179', chr1='chr1', pos1='96679615', gene1='RPL7P9', chr2='chr4', pos2='108625255', gene2='RPL34', sr='4'),
#  Event(eid='GF0180', tid='GF0180', chr1='chr10', pos1='120354654', gene1='RPL21P16', chr2='chr12', pos2='112408657', gene2='RPL6', sr='4'),
#  Event(eid='GF0181', tid='GF0181', chr1='chr10', pos1='120355211', gene1='RPL21P16', chr2='chr19', pos2='55388368', gene2='RPL28', sr='4'),
#  Event(eid='GF0182', tid='GF0182', chr1='chr15', pos1='82372888', gene1='UBE2Q2P2', chr2='chr19', pos2='39433215', gene2='RPS16', sr='5'),
#  Event(eid='GF0183', tid='GF0183', chr1='chr1', pos1='8861001', gene1='ENO1', chr2='chr19', pos2='49487618', gene2='RPL13A', sr='5'),
#  Event(eid='GF0184', tid='GF0184', chr1='chr12', pos1='56712430', gene1='NACA', chr2='chr16', pos2='1964627', gene2='RPS2', sr='4'),
#  Event(eid='GF0185', tid='GF0185', chr1='chr6', pos1='73373293', gene1='OOEP', chr2='chr7', pos2='137514243', gene2='DGKI', sr='4'),
#  Event(eid='GF0186', tid='GF0186', chr1='chr13', pos1='45341167', gene1='TPT1', chr2='chr17', pos2='28723913', gene2='RPL23A', sr='4'),
#  Event(eid='GF0187', tid='GF0187', chr1='chr16', pos1='18789118', gene1='RPS15A', chr2='chrX', pos2='154400912', gene2='RPL10', sr='4'),
#  Event(eid='GF0188', tid='GF0188', chr1='chr8', pos1='56074479', gene1='RPS20', chr2='chrX', pos2='154400913', gene2='RPL10', sr='6'),
#  Event(eid='GF0189', tid='GF0189', chr1='chr11', pos1='119018335', gene1='RPS25', chr2='chr16', pos2='18782967', gene2='RPS15A', sr='5'),
#  Event(eid='GF0190', tid='GF0190', chr1='chr11', pos1='46429151', gene1='AMBRA1', chr2='chr19', pos2='49491840', gene2='RPL13A', sr='5'),
#  Event(eid='GF0191', tid='GF0191', chr1='chr5', pos1='181243892', gene1='RACK1', chr2='chrM', pos2='5515', gene2='MT-ND2', sr='4'),
#  Event(eid='GF0192', tid='GF0192', chr1='chr11', pos1='8685845', gene1='RPL27A', chr2='chr19', pos2='49496447', gene2='RPS11', sr='6'),
#  Event(eid='GF0193', tid='GF0193', chr1='chr4', pos1='151104641', gene1='RPS3A', chr2='chr6', pos2='132814579', gene2='RPS12', sr='4'),
#  Event(eid='GF0194', tid='GF0194', chr1='chr16', pos1='1962060', gene1='RPS2', chr2='chr5', pos2='181243889', gene2='RACK1', sr='4'),
#  Event(eid='GF0195', tid='GF0195', chr1='chr19', pos1='5691666', gene1='RPL36', chr2='chrX', pos2='154398495', gene2='RPL10', sr='4'),
#  Event(eid='GF0196', tid='GF0196', chr1='chr11', pos1='119015711', gene1='RPS25', chr2='chr19', pos2='58387283', gene2='RPS5', sr='4'),
#  Event(eid='GF0197', tid='GF0197', chr1='chr15', pos1='82372902', gene1='UBE2Q2P2', chr2='chr7', pos2='44801627', gene2='PPIA', sr='4'),
#  Event(eid='GF0198', tid='GF0198', chr1='chr2', pos1='101006417', gene1='RPL31', chr2='chr8', pos2='98045535', gene2='RPL30', sr='4'),
#  Event(eid='GF0199', tid='GF0199', chr1='chr19', pos1='58394803', gene1='RPS5', chr2='chr4', pos2='151099636', gene2='RPS3A', sr='4')]

# %%
from collections import defaultdict
breakpoints = defaultdict(list)

for event in event_list:
    breakpoints[event.gene1].append(event.pos1)
    breakpoints[event.gene2].append(event.pos2)

# %%
breakpoints
# Out:
# defaultdict(list,
#             {'RPS8': ['44776032',
#               '44776032',
#               '44778739',
#               '44775583',
#               '44776069',
#               '44776032',
#               '44778737'],
#              'RPL13A': ['49491840',
#               '49487619',
#               '49491839',
#               '49491840',
#               '49491836',
#               '49487619',
#               '49491840',
#               '49491840',
#               '49489846',
#               '49491840',
#               '49487618',
#               '49491840'],
#              'RPLP2': ['809986',
#               '812875',
#               '809979',
#               '809975',
#               '809977',
#               '809977',
#               '812871',
#               '809976',
#               '809975',
#               '809987',
#               '812865'],
#              'RPS10-NUDT3': ['34417453',
#               '34417453',
#               '34417459',
#               '34426061',
#               '34417453',
#               '34417453',
#               '34417453',
#               '34417461',
#               '34417453',
#               '34426062',
#               '34417453',
#               '34417453',
#               '34426054',
#               '34426055',
#               '34426057'],
#              'RPS2': ['1962059',
#               '1964627',
#               '1964627',
#               '1964627',
#               '1964627',
#               '1962060',
#               '1962059',
#               '1964627',
#               '1962059',
#               '1964627',
#               '1964627',
#               '1962060',
#               '1962060',
#               '1964627',
#               '1962060'],
#              'PCNP': ['101576943',
#               '101576437',
#               '101576987',
#               '101576440',
#               '101576978'],
#              'COX8A': ['63974627',
#               '63974630',
#               '63976542',
#               '63974621',
#               '63974608'],
#              'RPL10': ['154400912',
#               '154398500',
#               '154400912',
#               '154398495',
#               '154398495',
#               '154398495',
#               '154398495',
#               '154400912',
#               '154400912',
#               '154400911',
#               '154398498',
#               '154400916',
#               '154400912',
#               '154398495',
#               '154400912',
#               '154400913',
#               '154398495'],
#              'RPL31': ['101002701',
#               '101002701',
#               '101006417',
#               '101006417',
#               '101006417',
#               '101006418',
#               '101006417',
#               '101002701',
#               '101006417'],
#              'RACK1': ['181236932',
#               '181236935',
#               '181243890',
#               '181243894',
#               '181236934',
#               '181236946',
#               '181236928',
#               '181236934',
#               '181236936',
#               '181243895',
#               '181236936',
#               '181236936',
#               '181236946',
#               '181236931',
#               '181243892',
#               '181243889'],
#              'RPS29': ['49586356',
#               '49586359',
#               '49583578',
#               '49583578',
#               '49586352',
#               '49586364',
#               '49586359',
#               '49586359',
#               '49583575',
#               '49583576',
#               '49586363'],
#              'RPS5': ['58394803', '58387283', '58387283', '58394803'],
#              'MT-RNR2': ['1682'],
#              'MT-CO1': ['7518'],
#              'TUBA1B': ['49129706'],
#              'HSP90B1': ['103947913'],
#              'RPS24': ['78040696',
#               '78033867',
#               '78040696',
#               '78040696',
#               '78033876',
#               '78040696'],
#              'RPS3': ['75399531',
#               '75399533',
#               '75405688',
#               '75399526',
#               '75399527',
#               '75405688',
#               '75399531',
#               '75399536',
#               '75399530',
#               '75399531',
#               '75399533',
#               '75399526',
#               '75399536',
#               '75399528'],
#              'RPL7A': ['133348920',
#               '133348920',
#               '133348920',
#               '133348920',
#               '133351422',
#               '133351425',
#               '133351425',
#               '133351422',
#               '133351425',
#               '133351417',
#               '133351425',
#               '133348920'],
#              'RPS18': ['33272091',
#               '33276504',
#               '33272089',
#               '33272087',
#               '33276502'],
#              'RPS3A': ['151104639',
#               '151104639',
#               '151104636',
#               '151099640',
#               '151104636',
#               '151099638',
#               '151099641',
#               '151104636',
#               '151099641',
#               '151099636',
#               '151104636',
#               '151104641',
#               '151099636'],
#              'ANK2': ['113214399', '113213967'],
#              'FTL': ['48966878', '48965321'],
#              'RPL3': ['39312883', '39312883', '39312883'],
#              'RPS20': ['56074494',
#               '56074489',
#               '56074493',
#               '56074494',
#               '56074484',
#               '56074494',
#               '56074479'],
#              'RPL7P9': ['96679628',
#               '96678796',
#               '96679628',
#               '96679628',
#               '96679628',
#               '96679615'],
#              'ACTG1': ['81510678', '81509970', '81509970'],
#              'RPSA': ['39406731', '39412437', '39412433', '39406729'],
#              'IL6ST': ['55944629'],
#              'RPL17-C18orf32': ['49488483'],
#              'RPS11': ['49496445',
#               '49499688',
#               '49499688',
#               '49496441',
#               '49499688',
#               '49499689',
#               '49499688',
#               '49496442',
#               '49499688',
#               '49497191',
#               '49496440',
#               '49499688',
#               '49499688',
#               '49499688',
#               '49496440',
#               '49496443',
#               '49499688',
#               '49496447'],
#              'RPL34': ['108625255',
#               '108621948',
#               '108625255',
#               '108621948',
#               '108621949',
#               '108625255'],
#              'RPL39': ['119786507'],
#              'RPL19': ['39204721',
#               '39201210',
#               '39204721',
#               '39201210',
#               '39204722',
#               '39204721',
#               '39200327',
#               '39200327',
#               '39200323',
#               '39201210',
#               '39204717'],
#              'RPL30': ['98041720',
#               '98045533',
#               '98041721',
#               '98045532',
#               '98041720',
#               '98041720',
#               '98041720',
#               '98045407',
#               '98045532',
#               '98041720',
#               '98041720',
#               '98041720',
#               '98045535'],
#              'RPS12': ['132814567', '132817563', '132814579'],
#              'PPIA': ['44801627', '44801627'],
#              'RPS25': ['119015711', '119018334', '119018335', '119015711'],
#              'AMBRA1': ['46429150',
#               '46429151',
#               '46428598',
#               '46428593',
#               '46429151'],
#              'RPS16': ['39433213',
#               '39433213',
#               '39433209',
#               '39435932',
#               '39435936',
#               '39433209',
#               '39433213',
#               '39433213',
#               '39433213',
#               '39433215'],
#              'RPS15P4': ['171517724', '171517222'],
#              'RPL28': ['55388367',
#               '55388369',
#               '55386347',
#               '55388369',
#               '55388368'],
#              'MT-ND3': ['10063'],
#              'RPS27A': ['55232806'],
#              'RPS14': ['150444237',
#               '150444237',
#               '150449725',
#               '150444237',
#               '150444237',
#               '150449724'],
#              'RPL12': ['127451390', '127447675', '127451391', '127451393'],
#              'TKT': ['53225653'],
#              'RPL23': ['38850080'],
#              'TPT1': ['45341174',
#               '45341162',
#               '45337178',
#               '45337178',
#               '45341165',
#               '45341167',
#               '45341174',
#               '45341167',
#               '45341167'],
#              'RP11-849F2.7': ['8377520', '8377522'],
#              'RPL8': ['144792142', '144789768', '144792142', '144789768'],
#              'RPL24': ['101686706'],
#              'RPL21P16': ['120355211',
#               '120354655',
#               '120355208',
#               '120355210',
#               '120354656',
#               '120354654',
#               '120355211'],
#              'KLK2': ['50879233', '50879233'],
#              'RPL6': ['112405189',
#               '112408657',
#               '112405189',
#               '112408656',
#               '112408657'],
#              'RPS15': ['1438808'],
#              'RPL35': ['124861943',
#               '124857885',
#               '124861950',
#               '124861940',
#               '124861555',
#               '124857885',
#               '124861555'],
#              'OOEP': ['73372919', '73373293'],
#              'RPL27': ['43002958', '42998456', '43002958', '43002958'],
#              'PIN4': ['72276234'],
#              'RPL27A': ['8683200', '8685845', '8685842', '8685845', '8685845'],
#              'DGKI': ['137513832', '137514243'],
#              'SNHG29': ['16439323'],
#              'RPL38': ['74203690', '74203703', '74203686', '74209879'],
#              'RPL14': ['40462279', '40462275'],
#              'RPL18': ['48619167'],
#              'RPL10P16': ['12643939'],
#              'RPL4': ['66504833', '66499323', '66504834'],
#              'EEF1A1P5': ['133019695'],
#              'RP11-306O13.1': ['153282744'],
#              'RPL22': ['6199583'],
#              'RPL11': ['23692602', '23696419', '23696417', '23692607'],
#              'RPL23A': ['28723933', '28723915', '28723913'],
#              'RPL5': ['92832049'],
#              'FAU': ['65122121', '65120986'],
#              'EEF1G': ['62559600', '62559600'],
#              'RPS15A': ['18782967',
#               '18789118',
#               '18789111',
#               '18789118',
#               '18789118',
#               '18782967'],
#              'ITM2A': ['79367315'],
#              'NBEAL1': ['203191327', '203190704'],
#              'UBE2Q2P2': ['82372888', '82372902'],
#              'ENO1': ['8861001'],
#              'NACA': ['56712430'],
#              'MT-ND2': ['5515'],
#              'RPL36': ['5691666']})

# %%
for event in event_list:
    event.pos1 = breakpoints[event.gene1][0]
    event.pos2 = breakpoints[event.gene2][0]

# %%
def write_to_infusion(event_list, file_name):
    header = "#id     ref1    break_pos1      region1 ref2    break_pos2      region2 num_span        num_paired      genes_1   genes_2 fusion_class"
    header = "\t".join(header.split())

    with open(file_name, "w") as f:
        f.write(f"{header}\n")

        ind = 0
        for event in event_list:
            
            num_paired = 1 
            num_span = 1

            chr1 = event.chr1[3:]
            chr2 = event.chr2[3:]

            if chr1 == "X":
                chr1 = "X"
            elif chr1 == "Y":
                chr1 = "Y"
            elif chr1 == "M":
                chr1 = "M"

            if chr2 == "X":
                chr2 = "X"
            elif chr2 == "Y":
                chr2 = "Y"
            elif chr2 == "M":
                chr2 = "M"
        
            if event.chr1 == event.chr2:
                fusion_class = "intra-chromosomal" 
                # num_span = event.sr
            else:
                fusion_class = "inter-chromosomal"
                # num_paired = event.sr 
            
            line = f"{ind}\t{chr1}\t{event.pos1}\t[{event.pos1},{int(event.pos1)+1}]\t{chr2}\t{event.pos2}\t[{event.pos2},{int(event.pos2) + 1}]\t{num_span}\t{num_paired}\t{event.gene1}\t{event.gene2}\t{fusion_class}\n"
            f.write(line)
            ind+=1

# %%
write_to_infusion(event_list, "vcap_002_gene_fusion_infusion_sr1_test.txt")

# %%
# !pwd
# Out:
# /Users/ylk4626/writing_project/deepchopper-paper/figures/supplementary_figures/gene_fusion_circle

# %%
len(event_list)
# Out:
# 199

# %%
gene_pairs = [tuple(sorted([event.gene1, event.gene2])) for event in event_list ]

# %%
len(gene_pairs)
# Out:
# 199

# %%
set(gene_pairs)
# Out:
# {('ACTG1', 'RPS16'),
#  ('ACTG1', 'RPS3'),
#  ('ACTG1', 'RPS5'),
#  ('AMBRA1', 'RPL12'),
#  ('AMBRA1', 'RPL13A'),
#  ('AMBRA1', 'RPS2'),
#  ('AMBRA1', 'RPS3A'),
#  ('AMBRA1', 'RPSA'),
#  ('ANK2', 'RPS18'),
#  ('ANK2', 'RPSA'),
#  ('COX8A', 'RPL10'),
#  ('COX8A', 'RPL6'),
#  ('COX8A', 'RPLP2'),
#  ('COX8A', 'RPS11'),
#  ('COX8A', 'RPS29'),
#  ('DGKI', 'OOEP'),
#  ('DGKI', 'RPS3A'),
#  ('EEF1A1P5', 'RPL30'),
#  ('EEF1G', 'RACK1'),
#  ('EEF1G', 'RPLP2'),
#  ('ENO1', 'RPL13A'),
#  ('FAU', 'RPL7A'),
#  ('FAU', 'RPS10-NUDT3'),
#  ('FTL', 'RPL19'),
#  ('FTL', 'RPL7A'),
#  ('HSP90B1', 'TUBA1B'),
#  ('IL6ST', 'RPS3'),
#  ('ITM2A', 'RPL7A'),
#  ('KLK2', 'RPL10'),
#  ('KLK2', 'RPL19'),
#  ('MT-CO1', 'MT-RNR2'),
#  ('MT-ND2', 'RACK1'),
#  ('MT-ND3', 'RPL28'),
#  ('NACA', 'RPS2'),
#  ('NBEAL1', 'RPS3A'),
#  ('OOEP', 'RPS3'),
#  ('PCNP', 'RPL17-C18orf32'),
#  ('PCNP', 'RPL7A'),
#  ('PCNP', 'RPS2'),
#  ('PCNP', 'RPS3A'),
#  ('PIN4', 'RPS11'),
#  ('PPIA', 'RPS12'),
#  ('PPIA', 'UBE2Q2P2'),
#  ('RACK1', 'RPL10'),
#  ('RACK1', 'RPL13A'),
#  ('RACK1', 'RPL30'),
#  ('RACK1', 'RPL31'),
#  ('RACK1', 'RPL35'),
#  ('RACK1', 'RPL6'),
#  ('RACK1', 'RPL8'),
#  ('RACK1', 'RPLP2'),
#  ('RACK1', 'RPS10-NUDT3'),
#  ('RACK1', 'RPS11'),
#  ('RACK1', 'RPS15A'),
#  ('RACK1', 'RPS18'),
#  ('RACK1', 'RPS2'),
#  ('RACK1', 'RPS3A'),
#  ('RP11-306O13.1', 'RPSA'),
#  ('RP11-849F2.7', 'RPL35'),
#  ('RP11-849F2.7', 'RPL8'),
#  ('RPL10', 'RPL12'),
#  ('RPL10', 'RPL13A'),
#  ('RPL10', 'RPL18'),
#  ('RPL10', 'RPL21P16'),
#  ('RPL10', 'RPL27'),
#  ('RPL10', 'RPL27A'),
#  ('RPL10', 'RPL36'),
#  ('RPL10', 'RPL39'),
#  ('RPL10', 'RPS10-NUDT3'),
#  ('RPL10', 'RPS11'),
#  ('RPL10', 'RPS15A'),
#  ('RPL10', 'RPS16'),
#  ('RPL10', 'RPS20'),
#  ('RPL10P16', 'RPL7A'),
#  ('RPL11', 'RPL38'),
#  ('RPL11', 'RPLP2'),
#  ('RPL11', 'RPS14'),
#  ('RPL11', 'RPS29'),
#  ('RPL12', 'RPL24'),
#  ('RPL12', 'RPS14'),
#  ('RPL13A', 'RPL19'),
#  ('RPL13A', 'RPL22'),
#  ('RPL13A', 'RPL28'),
#  ('RPL13A', 'RPL34'),
#  ('RPL13A', 'RPL35'),
#  ('RPL13A', 'RPS24'),
#  ('RPL13A', 'RPS3'),
#  ('RPL13A', 'RPS8'),
#  ('RPL14', 'RPS8'),
#  ('RPL14', 'TPT1'),
#  ('RPL19', 'RPL28'),
#  ('RPL19', 'RPL38'),
#  ('RPL19', 'RPL7A'),
#  ('RPL19', 'RPLP2'),
#  ('RPL19', 'RPS10-NUDT3'),
#  ('RPL19', 'RPS16'),
#  ('RPL19', 'RPS2'),
#  ('RPL19', 'RPS29'),
#  ('RPL21P16', 'RPL28'),
#  ('RPL21P16', 'RPL6'),
#  ('RPL21P16', 'RPS11'),
#  ('RPL21P16', 'RPS3'),
#  ('RPL21P16', 'RPS8'),
#  ('RPL23', 'RPL30'),
#  ('RPL23A', 'RPL34'),
#  ('RPL23A', 'RPL35'),
#  ('RPL23A', 'TPT1'),
#  ('RPL27', 'RPS2'),
#  ('RPL27', 'RPS29'),
#  ('RPL27A', 'RPS10-NUDT3'),
#  ('RPL27A', 'RPS11'),
#  ('RPL27A', 'RPS20'),
#  ('RPL27A', 'RPS3'),
#  ('RPL28', 'RPS15'),
#  ('RPL3', 'RPS11'),
#  ('RPL3', 'RPS20'),
#  ('RPL3', 'RPS3'),
#  ('RPL30', 'RPL31'),
#  ('RPL30', 'RPS10-NUDT3'),
#  ('RPL30', 'RPS11'),
#  ('RPL30', 'RPS2'),
#  ('RPL30', 'RPS24'),
#  ('RPL30', 'RPS25'),
#  ('RPL30', 'RPS29'),
#  ('RPL30', 'RPS3'),
#  ('RPL30', 'RPS8'),
#  ('RPL30', 'SNHG29'),
#  ('RPL31', 'RPL38'),
#  ('RPL31', 'RPL5'),
#  ('RPL31', 'RPL7P9'),
#  ('RPL31', 'RPS10-NUDT3'),
#  ('RPL31', 'RPS2'),
#  ('RPL31', 'RPS5'),
#  ('RPL31', 'RPS8'),
#  ('RPL34', 'RPL35'),
#  ('RPL34', 'RPL7P9'),
#  ('RPL34', 'RPS11'),
#  ('RPL34', 'RPS20'),
#  ('RPL35', 'RPL4'),
#  ('RPL35', 'RPS15A'),
#  ('RPL38', 'TPT1'),
#  ('RPL4', 'RPS2'),
#  ('RPL4', 'RPS20'),
#  ('RPL6', 'RPS11'),
#  ('RPL6', 'RPS15A'),
#  ('RPL7A', 'RPS14'),
#  ('RPL7A', 'RPS24'),
#  ('RPL7A', 'RPS29'),
#  ('RPL7A', 'RPS8'),
#  ('RPL7A', 'TPT1'),
#  ('RPL7P9', 'RPLP2'),
#  ('RPL7P9', 'RPS11'),
#  ('RPL7P9', 'RPS24'),
#  ('RPL7P9', 'RPS29'),
#  ('RPL8', 'RPS3'),
#  ('RPL8', 'RPS3A'),
#  ('RPLP2', 'RPS10-NUDT3'),
#  ('RPLP2', 'RPS11'),
#  ('RPLP2', 'RPS16'),
#  ('RPLP2', 'RPS24'),
#  ('RPLP2', 'RPS3A'),
#  ('RPS10-NUDT3', 'RPS16'),
#  ('RPS10-NUDT3', 'RPS20'),
#  ('RPS10-NUDT3', 'RPS27A'),
#  ('RPS10-NUDT3', 'RPS29'),
#  ('RPS10-NUDT3', 'RPS3'),
#  ('RPS10-NUDT3', 'TPT1'),
#  ('RPS11', 'RPS16'),
#  ('RPS11', 'RPS3'),
#  ('RPS11', 'RPS3A'),
#  ('RPS11', 'RPS8'),
#  ('RPS12', 'RPS3A'),
#  ('RPS12', 'TPT1'),
#  ('RPS14', 'RPS16'),
#  ('RPS14', 'RPS18'),
#  ('RPS14', 'RPS20'),
#  ('RPS15A', 'RPS18'),
#  ('RPS15A', 'RPS25'),
#  ('RPS15P4', 'RPS16'),
#  ('RPS15P4', 'RPSA'),
#  ('RPS16', 'RPS3A'),
#  ('RPS16', 'UBE2Q2P2'),
#  ('RPS18', 'TPT1'),
#  ('RPS2', 'RPS29'),
#  ('RPS2', 'RPS3'),
#  ('RPS2', 'TKT'),
#  ('RPS2', 'TPT1'),
#  ('RPS24', 'RPS3'),
#  ('RPS25', 'RPS29'),
#  ('RPS25', 'RPS5'),
#  ('RPS3', 'TPT1'),
#  ('RPS3A', 'RPS5')}
